# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
from sklearn.preprocessing import LabelEncoder

# %%
# Read the Flu dataset
df = pd.read_csv('flu_data.csv')
df.dropna(inplace=True)
data = df[['Vaccin','HndWshQual','HndWshFreq','SociDist','NoFaceContact','RespEttiqu','PersnDist','HandSanit']]
data.head(10)
data.describe()
# Out:
#            Vaccin  HndWshQual  HndWshFreq    SociDist  NoFaceContact  \
# count  351.000000  351.000000  351.000000  351.000000     351.000000
# mean     3.393162    3.917379    3.222222    2.911681       2.467236
# std      1.368778    1.020650    1.132212    1.176268       1.255130
# min      1.000000    1.000000    1.000000    1.000000       1.000000
# 25%      2.000000    3.000000    3.000000    2.000000       2.000000
# 50%      3.000000    4.000000    3.000000    3.000000       2.000000
# 75%      5.000000    5.000000    4.000000    3.000000       3.000000
# max      9.000000    5.000000    5.000000    5.000000       9.000000
#
#        RespEttiqu   PersnDist   HandSanit
# count  351.000000  351.000000  351.000000
# mean     4.193732    3.407407    2.806268
# std      1.212820    1.149833    1.606083
# min      1.000000    1.000000    1.000000
# 25%      3.000000    3.000000    1.000000
# 50%      5.000000    3.000000    3.000000
# 75%      5.000000    4.000000    4.000000
# ...

# %%
le = LabelEncoder()
df.Female= le.fit_transform(df.Female.values)
df.Flu= le.fit_transform(df.Flu.values)
df.Sick= le.fit_transform(df.Sick.values)
df.head(10)
# Out:
#     Student  Vaccin  HndWshQual  HndWshFreq  SociDist  NoFaceContact  \
# 0         1       3           4           4         2              1
# 1         2       2           4           4         5              2
# 2         3       3           2           2         2              3
# 4         5       2           5           3         3              2
# 5         6       2           5           5         3              3
# 6         7       5           4           3         3              2
# 9        10       2           4           3         2              2
# 10       11       3           4           3         3              2
# 11       12       3           1           3         5              1
# 12       13       2           4           1         4              2
#
#     RespEttiqu  PersnDist  HandSanit   Risk  Complications  Barriers  \
# 0            5          1          1 -0.770         -1.453     0.000
# ...

# %%
print(df.Female.unique())
print(df.Sick.unique())
print(df.Flu.unique())
# Out:
# [1 0]
# [0 1 2]
# [0 1]

# %%
print(df.Female.count())
print(df.Sick.count())
print(df.Flu.count())
# Out:
# 351
# 351
# 351

# %%
print(df.Female.mode())
print(df.Sick.mode())
print(df.Flu.mode())
# Out:
# 0    1
# Name: Female, dtype: int64
# 0    1
# Name: Sick, dtype: int64
# 0    0
# Name: Flu, dtype: int64

# %%
df['SociDist'].corr(df['PersnDist'])
# Out:
# 0.11329107160936322

# %%
df.corr()
# Out:
#                 Student    Vaccin  HndWshQual  HndWshFreq  SociDist  \
# Student        1.000000  0.084523    0.016987   -0.105407 -0.075199
# Vaccin         0.084523  1.000000   -0.042126   -0.076817  0.039374
# HndWshQual     0.016987 -0.042126    1.000000    0.300265  0.172393
# HndWshFreq    -0.105407 -0.076817    0.300265    1.000000  0.145645
# SociDist      -0.075199  0.039374    0.172393    0.145645  1.000000
# NoFaceContact -0.022948 -0.050688    0.079287    0.063444  0.070606
# RespEttiqu     0.042253  0.019388    0.151455    0.155821 -0.005997
# PersnDist     -0.001906  0.025012    0.094497   -0.003902  0.113291
# HandSanit     -0.003420  0.023050    0.188905    0.151011  0.137617
# Risk          -0.117545  0.095313   -0.044932    0.016695  0.024210
# Complications -0.059556 -0.032949   -0.097873   -0.074318  0.130903
# Barriers      -0.111192 -0.106940   -0.258689   -0.198399 -0.047828
# Inefficacy    -0.088841 -0.010694   -0.129131   -0.164768 -0.179443
# ...
